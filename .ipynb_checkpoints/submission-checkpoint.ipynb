# %% [markdown]
# # Agent submission

# %%
from kaggle_environments import make
# Out:
# Loading environment football failed:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.9 from "C:\Users\Yuvraj\anaconda3\envs\luxai\python.exe"
#   * The NumPy version is: "1.20.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# Loading environment halite failed:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.9 from "C:\Users\Yuvraj\anaconda3\envs\luxai\python.exe"
#   * The NumPy version is: "1.20.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# C:\Users\Yuvraj\anaconda3\envs\luxai\lib\site-packages\numpy\__init__.py:143: UserWarning: mkl-service package failed to import, therefore Intel(R) MKL initialization ensuring its correct out-of-the box operation under condition when Gnu OpenMP had already been loaded by Python process is not assured. Please install mkl-service package, see http://github.com/IntelPython/mkl-service
#   from . import _distributor_init

# %%
# %%writefile agent.py
# Completely new agent type from scratch. Seems promising and fun! We're not begrudged by the starter kit's doodoo logic (although the structure is still there).
# We have clear ways to improve this. See sticky notes.
from lux.game import Game
from lux.game_map import Cell, RESOURCE_TYPES, Position
from lux.constants import Constants
from lux.game_objects import Unit
from lux.game_constants import GAME_CONSTANTS
from lux import annotate
import math
import sys


### Define helper functions
# Fix using A* so it works with this too
def get_shortest_path(start, end, world, entities, blast_tiles=None, player_invulnerable=False,
                      ignore_bomb=False) -> object:
    """
    Finds the shortest path from the start node to the end node.
    Returns an array of (x,y) tuples. Uses A* search algorithm
    """
    world_width, world_height = get_world_dimension(world)
    if blast_tiles is None:
        blast_tiles = []
    if start is None or end is None:
        return None

    # create a list for all nodes to visit and have been visited
    queue = []
    visited = []

    # create a start node and end node
    start_node = Node(start, None)
    goal_node = Node(end, None)

    queue.append(start_node)

    while len(queue) > 0:
        # sort the open list to get the node with the lowest cost first
        queue.sort()

        # get the node with the lowest cost
        current_node = queue.pop(0)

        # add the current node to the closed list
        visited.append(current_node)

        # check if we have reached the goal, return the path
        if current_node == goal_node:
            path = []
            while current_node != start_node:
                path.append(current_node.position)
                current_node = current_node.parent
            # return reversed
            return path[::-1]

        # loop through each neighbour
        neighbours = get_surrounding_tiles(current_node.position, world_width, world_height)

        for tile in neighbours:
            if (tile in blast_tiles) and not player_invulnerable:
                continue  # skip if blast tile

            if not is_walkable(tile, entities, ignore_bomb=ignore_bomb):
                continue  # skip if not walkable

            neighbour = Node(tile, current_node)

            if neighbour in visited:
                continue  # skip if visited

            # generate heuristics
            neighbour.dist_to_start = manhattan_distance(neighbour.position, start_node.position)
            neighbour.dist_to_goal = manhattan_distance(neighbour.position, goal_node.position)
            neighbour.total_cost = neighbour.dist_to_start + neighbour.dist_to_goal

            # check if neighbour is in the open list and if it has a lower total value
            if can_enqueue(queue, neighbour):
                queue.append(neighbour)

    return None  # no path found


# this snippet finds all resources stored on the map and puts them into a list so we can search over them
def find_resources(game_state):
	resource_tiles: list[Cell] = []
	width, height = game_state.map_width, game_state.map_height
	for y in range(height):
		for x in range(width):
			cell = game_state.map.get_cell(x, y)
			if cell.has_resource():
				resource_tiles.append(cell)
	return resource_tiles

# the next snippet finds the closest resources that we can mine given position on a map
def find_closest_resources(pos, player, resource_tiles):
	closest_dist = math.inf
	closest_resource_tile = None
	for resource_tile in resource_tiles:
		# we skip over resources that we can't mine due to not having researched them
		if resource_tile.resource.type == Constants.RESOURCE_TYPES.COAL and not player.researched_coal(): continue
		if resource_tile.resource.type == Constants.RESOURCE_TYPES.URANIUM and not player.researched_uranium(): continue
		dist = resource_tile.pos.distance_to(pos)
		if dist < closest_dist:
			closest_dist = dist
			closest_resource_tile = resource_tile
	return closest_resource_tile

def find_closest_city_tile(pos, player):
	"""
	pos: Position Object
	player: Player object


	Returns 'closest_city_tile': CityTile Object 
	"""
	closest_city_tile = None
	if len(player.cities) > 0:
		closest_dist = math.inf
		# the cities are stored as a dictionary mapping city id to the city object, which has a citytiles field that
		# contains the information of all citytiles in that city
		for k, city in player.cities.items():
			for city_tile in city.citytiles:
				dist = city_tile.pos.distance_to(pos)
				if dist < closest_dist:
					closest_dist = dist
					closest_city_tile = city_tile
	return closest_city_tile



############## END OF HELPER FUNCTIONS ###############
######################################################
######################################################
######################################################
######################################################



#### Agent 3 - Devastator (pre-taking their code) 
#Aim of the game: Fucking duplicate as fast as you can. Duplicate and eat the world.

game_state = None
def agent(observation, configuration):
	########### Code / Bot starts here ############
	###############################################

	global game_state

	### Do not edit ###
	if observation["step"] == 0:
		game_state = Game()
		game_state._initialize(observation["updates"])
		game_state._update(observation["updates"][2:])
		game_state.id = observation.player
	else:
		game_state._update(observation["updates"])
	
	actions = []
	## Helper functions
	### VOID FUNCTIONS BELOW
	def researched(resource):
		"""
		given a Resource object, return whether the player has researched the resource type
		"""
		if resource.type == Constants.RESOURCE_TYPES.WOOD:
			return True
		if resource.type == Constants.RESOURCE_TYPES.COAL \
			and player.research_points >= GAME_CONSTANTS['PARAMETERS']['RESEARCH_REQUIREMENTS']['COAL']:
				return True
		if resource.type == Constants.RESOURCE_TYPES.URANIUM \
			and player.research_points >= GAME_CONSTANTS['PARAMETERS']['RESEARCH_REQUIREMENTS']['URANIUM']:
				return True
		return False

	def get_cells(cell_type):  # resource, researched resource, player citytile, enemy citytile, empty
		"""
		Given a cell type, returns a list of Cell objects of the given type
		Options are: ['resource', 'researched resource', 'player citytile', 'enemy citytile', 'empty']
		"""
		cells_of_type = []
		for y in range(height):
			for x in range(width):
				cell = game_state.map.get_cell(x, y)
				if (
					   ( cell_type == 'resource' and cell.has_resource() ) \
					or ( cell_type == 'researched resource' and cell.has_resource() and researched(cell.resource) ) \
					or ( cell_type == 'player citytile' and cell.citytile is not None and cell.citytile.team == observation.player ) \
					or ( cell_type == 'enemy citytile' and cell.citytile is not None and cell.citytile.team != observation.player ) \
					or ( cell_type == 'empty' and cell.citytile is None and not cell.has_resource() )
				):
					cells_of_type.append(cell)

		return cells_of_type

	def find_nearest_position(target_position, option_positions):
		# Should we change to find nearest cell?
		"""
		target_position: Position object
		option_positions: list of Position, Cell, or Unit objects (must all be the same type)
		finds the closest option_position to the target_position
		
		Returns: Closest_position -> Position object
		"""

		# convert option_positions list to Position objects
		if type(option_positions[0]) in [Cell, Unit]:
			option_positions = [cell.pos for cell in option_positions]

		# find closest position
		closest_dist = math.inf
		closest_position = None
		for position in option_positions:
			dist = target_position.distance_to(position)
			if dist < closest_dist:
				closest_dist = dist
				closest_position = position

		return closest_position

	target_tiles = [] # to help avoid collisions. You'd want to put this somewhere inside the agent (so it can append target tiles over time and figure shit out)
	#That's our 2nd best alternative since we haven't done linear assignment problem thingy yet.
	def move_unit(unit, position):
		"""
		moves the given unit towards the given position
		also checks basic collision detection, and adds annotations for any movement
		"""

		direction = unit.pos.direction_to(position)
		target_tile = unit.pos.translate(direction, 1)

		# if target_tile is not being targeted already, move there
		if target_tile not in target_tiles or target_tile in [tile.pos for tile in citytile_cells]:
			target_tiles.append(target_tile)
			actions.append(unit.move(direction))
			actions.append(annotate.line(unit.pos.x, unit.pos.y, position.x, position.y))

		# else, if it is being targetted mark an X on the map
		else:
			actions.append(annotate.x(target_tile.x, target_tile.y))


	def go_home(unit, citytile_cells):
		"""
		moves the given unit towards the nearest citytile
		"""

		nearest_citytile_position = find_nearest_position(unit.pos, citytile_cells)
		move_unit(unit, nearest_citytile_position)


	###############################################
	#################### Our Code  ################
	###############################################

	
	#### Fucking ALGO CODE
	player = game_state.players[observation.player]
	opponent = game_state.players[(observation.player + 1) % 2]
	width, height = game_state.map.width, game_state.map.height

	# add debug statements like so!
	if game_state.turn == 0:
		print("I am devastator agent!!", file=sys.stderr)

	resource_tiles = find_resources(game_state)
	citytile_cells = get_cells('player citytile')
	num_citytiles = len(citytile_cells)
	is_night = game_state.turn % 40 > 30 # Bool - True if it's night time
#     num_units = len(player.units)
#     print("Num citytile or units", num_citytiles, num_units, file=sys.stderr)
	
	
	### City actions / citybuilding (put this shit ijn functions later)
	"""Priority list for cities:
	Worker
	Research"""
	for k, city in player.cities.items():
		## Running through each citytile for logic
		for citytile in city.citytiles:
			if citytile.can_act():
				# Either make a new worker or just research.
				if len(citytile_cells) > len(player.units): 
					action = citytile.build_worker()
					actions.append(action)

				else:
					action = citytile.research()
					actions.append(action)

	### Unit Actions ####
	
	for unit in player.units:
		"""
		Priority list for units:
		Place a city if possible (should we put a weight on adjacent cities?)
		
		else;
			Mine
			If cargo full and you don't wanna place;
				Return to city

		"""
		# TODO - We could have the bot find the closest empty cell to place a city too. Actually, let's do that now.
		closest_city_tile = find_closest_city_tile(unit.pos, player) 
		## Code for Workers ##
		if unit.is_worker() and unit.can_act():

			# Check if it has no cargo space
			if unit.get_cargo_space_left() == 0 and unit.can_build(game_state.map): #I.e it's at 100 cargo space (the amt required to build a city):
				print("I'm gonna build a city because I have full inventory + I can build!", file=sys.stderr)
				actions.append(unit.build_city())
			
			# We're full but unbuildable rn, find the closest place to build to. THis might go horribly wroong lol
			elif unit.get_cargo_space_left() == 0:
				empty_cells = get_cells('empty')
				closest_empty_cell_pos = find_nearest_position(unit.pos, empty_cells)
				move_unit(unit, closest_empty_cell_pos)
			
			else: #I.e you might have 0 cargo but can't build
				# Mine if you have cargo space  
				# Else go home
				if unit.get_cargo_space_left() > 0:
					closest_resource_tile = find_closest_resources(unit.pos, player, resource_tiles)
					if closest_resource_tile is not None and not is_night:
						# create a move action to move this unit in the direction of the closest resource tile and add to our actions list
						move_unit(unit, closest_resource_tile.pos)
					else:
						print("Well.. Shit. I'm unit,", unit.id ,"Apparently I can't find any resources.", file=sys.stderr)

					# go_mine(unit, resources) -> Make this void function sometime? (i.e function that does stuff)

				else:
					# If we have no cargo space & can't build.
					go_home(unit, citytile_cells)
				#  Go home 
					
					
	print("Super secret. Turn:", game_state.turn, "Action list:", actions, file=sys.stderr)
	
	return actions

# %%
# !tar -czvf devastate2.tar.gz __init__.py agent.py main.py lux
# Out:
# a __init__.py
# a agent.py
# a main.py
# a lux
# a lux/annotate.py
# a lux/constants.py
# a lux/game.py
# a lux/game_constants.json
# a lux/game_constants.py
# a lux/game_map.py
# a lux/game_objects.py
# a lux/__init__.py
# a lux/__pycache__
# a lux/__pycache__/annotate.cpython-37.pyc
# a lux/__pycache__/annotate.cpython-39.pyc
# a lux/__pycache__/constants.cpython-37.pyc
# a lux/__pycache__/constants.cpython-39.pyc
# a lux/__pycache__/game.cpython-37.pyc
# a lux/__pycache__/game.cpython-39.pyc
# a lux/__pycache__/game_constants.cpython-37.pyc
# a lux/__pycache__/game_constants.cpython-39.pyc
# a lux/__pycache__/game_map.cpython-37.pyc
# a lux/__pycache__/game_map.cpython-39.pyc
# a lux/__pycache__/game_objects.cpython-37.pyc
# a lux/__pycache__/game_objects.cpython-39.pyc
# a lux/__pycache__/__init__.cpython-37.pyc
# a lux/__pycache__/__init__.cpython-39.pyc

# %%
## This is just to see it works (you'll have to comment out %%writefile tho)
env = make("lux_ai_2021", configuration={"loglevel": 2, "annotations": True}, debug=True)
steps = env.run([agent, "simple_agent"])
# Out:
# I am devastator agent!!
# Super secret. Turn: 0 Action list: ['r 7 6', 'm u_1 n', 'dl 7 6 7 5']
# Super secret. Turn: 1 Action list: []
# Super secret. Turn: 2 Action list: ['m u_1 n', 'dl 7 5 7 4']
# Super secret. Turn: 3 Action list: []
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 4 Action list: ['bcity u_1']
# Super secret. Turn: 5 Action list: ['bw 7 4', 'm u_1 s', 'dl 7 4 7 5']
# Super secret. Turn: 6 Action list: ['m u_3 s', 'dl 7 4 7 5']
# [WARN] (match_wiE36PyPlvkT) - turn 6; Unit u_3 collided when trying to move s to (7, 5)
# Super secret. Turn: 7 Action list: ['m u_1 n', 'dl 7 5 7 3', 'm u_3 s', 'dl 7 4 7 5']
# Super secret. Turn: 8 Action list: ['m u_1 s', 'dl 7 4 7 5']
# [WARN] (match_wiE36PyPlvkT) - turn 8; Unit u_1 collided when trying to move s to (7, 5)
# Super secret. Turn: 9 Action list: ['m u_1 s', 'dl 7 4 7 5', 'm u_3 n', 'dl 7 5 7 3']
# Super secret. Turn: 10 Action list: ['r 7 6', 'm u_3 s', 'dl 7 4 7 5']
# [WARN] (match_wiE36PyPlvkT) - turn 10; Unit u_3 collided when trying to move s to (7, 5)
# Super secret. Turn: 11 Action list: ['m u_1 n', 'dl 7 5 7 3', 'm u_3 s', 'dl 7 4 7 5']
# Super secret. Turn: 12 Action list: ['m u_1 s', 'dl 7 4 7 5']
# [WARN] (match_wiE36PyPlvkT) - turn 12; Unit u_1 collided when trying to move s to (7, 5)
# Super secret. Turn: 13 Action list: ['m u_1 s', 'dl 7 4 7 5', 'm u_3 n', 'dl 7 5 7 3']
# Super secret. Turn: 14 Action list: ['m u_3 s', 'dl 7 4 7 5']
# [WARN] (match_wiE36PyPlvkT) - turn 14; Unit u_3 collided when trying to move s to (7, 5)
# Super secret. Turn: 15 Action list: ['r 7 4', 'm u_1 n', 'dl 7 5 7 3', 'm u_3 s', 'dl 7 4 7 5']
# Super secret. Turn: 16 Action list: ['m u_1 s', 'dl 7 4 7 5']
# [WARN] (match_wiE36PyPlvkT) - turn 16; Unit u_1 collided when trying to move s to (7, 5)
# Super secret. Turn: 17 Action list: ['m u_1 s', 'dl 7 4 7 5', 'm u_3 n', 'dl 7 5 7 3']
# Super secret. Turn: 18 Action list: ['m u_3 s', 'dl 7 4 7 5']
# [WARN] (match_wiE36PyPlvkT) - turn 18; Unit u_3 collided when trying to move s to (7, 5)
# Super secret. Turn: 19 Action list: ['m u_1 n', 'dl 7 5 7 3', 'm u_3 s', 'dl 7 4 7 5']
# Super secret. Turn: 20 Action list: ['r 7 6', 'm u_1 s', 'dl 7 4 7 5']
# [WARN] (match_wiE36PyPlvkT) - turn 20; Unit u_1 collided when trying to move s to (7, 5)
# Super secret. Turn: 21 Action list: ['m u_1 s', 'dl 7 4 7 5', 'm u_3 n', 'dl 7 5 7 3']
# Super secret. Turn: 22 Action list: ['m u_3 s', 'dl 7 4 7 5']
# [WARN] (match_wiE36PyPlvkT) - turn 22; Unit u_3 collided when trying to move s to (7, 5)
# Super secret. Turn: 23 Action list: ['m u_1 n', 'dl 7 5 7 3', 'm u_3 s', 'dl 7 4 7 5']
# Super secret. Turn: 24 Action list: ['m u_1 s', 'dl 7 4 7 5']
# [WARN] (match_wiE36PyPlvkT) - turn 24; Unit u_1 collided when trying to move s to (7, 5)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 25 Action list: ['r 7 4', 'm u_1 s', 'dl 7 4 6 5', 'bcity u_3']
# [WARN] (match_wiE36PyPlvkT) - turn 25; Unit u_1 collided when trying to move s to (7, 5)
# Super secret. Turn: 26 Action list: ['bw 7 5', 'm u_1 s', 'dl 7 4 6 5', 'm u_3 w', 'dl 7 5 6 5']
# Super secret. Turn: 27 Action list: ['m u_1 w', 'dl 7 5 6 5', 'dx 6 5']
# [WARN] (match_wiE36PyPlvkT) - turn 27; Unit u_1 collided when trying to move w to (6, 5)
# Super secret. Turn: 28 Action list: ['m u_1 w', 'dl 7 5 6 5', 'dx 6 5', 'dx 6 5']
# [WARN] (match_wiE36PyPlvkT) - turn 28; Unit u_1 collided when trying to move w to (6, 5)
# Super secret. Turn: 29 Action list: ['m u_1 w', 'dl 7 5 6 5', 'dx 6 5', 'dx 6 5']
# [WARN] (match_wiE36PyPlvkT) - turn 29; Unit u_1 collided when trying to move w to (6, 5)
# Super secret. Turn: 30 Action list: ['r 7 6', 'm u_1 w', 'dl 7 5 6 5', 'dx 6 5', 'dx 6 5']
# [WARN] (match_wiE36PyPlvkT) - turn 30; Unit u_1 collided when trying to move w to (6, 5)
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Super secret. Turn: 31 Action list: []
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Super secret. Turn: 32 Action list: []
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Super secret. Turn: 33 Action list: []
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Super secret. Turn: 34 Action list: []
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Super secret. Turn: 35 Action list: ['r 7 4']
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Super secret. Turn: 36 Action list: ['r 7 5']
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Super secret. Turn: 37 Action list: []
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Super secret. Turn: 38 Action list: []
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Super secret. Turn: 39 Action list: []
# Super secret. Turn: 40 Action list: ['r 7 6', 'm u_1 w', 'dl 7 5 6 5', 'dx 6 5', 'dx 6 5']
# [WARN] (match_wiE36PyPlvkT) - turn 40; Unit u_1 collided when trying to move w to (6, 5)
# Super secret. Turn: 41 Action list: ['m u_1 e', 'dl 7 5 8 5', 'm u_3 e', 'dl 6 5 8 5', 'dx 8 5']
# Super secret. Turn: 42 Action list: ['m u_3 e', 'dl 7 5 8 5', 'dx 8 5']
# [WARN] (match_wiE36PyPlvkT) - turn 42; Unit u_3 collided when trying to move e to (8, 5)
# Super secret. Turn: 43 Action list: ['m u_1 c', 'dl 8 5 8 5', 'dx 8 5', 'dx 8 5']
# Super secret. Turn: 44 Action list: ['m u_1 c', 'dl 8 5 8 5', 'dx 8 5', 'dx 8 5']
# Super secret. Turn: 45 Action list: ['r 7 4', 'm u_1 c', 'dl 8 5 8 5', 'dx 8 5', 'dx 8 5']
# Super secret. Turn: 46 Action list: ['r 7 5', 'm u_1 n', 'dl 8 5 8 4', 'm u_3 e', 'dl 7 5 8 5', 'dx 8 5']
# Super secret. Turn: 47 Action list: ['m u_4 e', 'dl 7 5 8 5']
# [WARN] (match_wiE36PyPlvkT) - turn 47; Unit u_4 collided when trying to move e to (8, 5)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 48 Action list: ['bcity u_1', 'm u_3 c', 'dl 8 5 8 5', 'dx 8 5']
# Super secret. Turn: 49 Action list: ['bw 8 4', 'm u_1 n', 'dl 8 4 7 1', 'm u_3 n', 'dl 8 5 7 1', 'm u_4 n', 'dl 7 5 7 1']
# Super secret. Turn: 50 Action list: ['r 7 6', 'm u_3 n', 'dl 8 4 7 1', 'm u_4 n', 'dl 7 4 7 1', 'dx 8 3']
# [WARN] (match_wiE36PyPlvkT) - turn 50; Unit u_3 collided when trying to move n to (8, 3)
# Super secret. Turn: 51 Action list: ['m u_1 n', 'dl 8 3 7 1', 'm u_3 n', 'dl 8 4 7 1', 'dx 8 3']
# Super secret. Turn: 52 Action list: ['m u_4 n', 'dl 7 3 7 1', 'm u_5 n', 'dl 8 4 7 1']
# [WARN] (match_wiE36PyPlvkT) - turn 52; Unit u_5 collided when trying to move n to (8, 3)
# Super secret. Turn: 53 Action list: ['m u_1 n', 'dl 8 2 7 1', 'm u_3 n', 'dl 8 3 7 1', 'm u_5 n', 'dl 8 4 7 1']
# Super secret. Turn: 54 Action list: ['m u_4 n', 'dl 7 2 7 1']
# Super secret. Turn: 55 Action list: ['r 7 4', 'm u_1 w', 'dl 8 1 7 1', 'm u_3 n', 'dl 8 2 7 1', 'm u_5 n', 'dl 8 3 7 1']
# [WARN] (match_wiE36PyPlvkT) - turn 55; Unit u_1 collided when trying to move w to (7, 1)
# [WARN] (match_wiE36PyPlvkT) - turn 55; Unit u_3 collided when trying to move n to (8, 1)
# [WARN] (match_wiE36PyPlvkT) - turn 55; Unit u_5 collided when trying to move n to (8, 2)
# Super secret. Turn: 56 Action list: ['r 7 5', 'm u_1 w', 'dl 8 1 7 1', 'm u_3 n', 'dl 8 2 7 1', 'dx 7 1', 'm u_5 n', 'dl 8 3 7 1']
# [WARN] (match_wiE36PyPlvkT) - turn 56; Unit u_1 collided when trying to move w to (7, 1)
# [WARN] (match_wiE36PyPlvkT) - turn 56; Unit u_3 collided when trying to move n to (8, 1)
# [WARN] (match_wiE36PyPlvkT) - turn 56; Unit u_5 collided when trying to move n to (8, 2)
# Super secret. Turn: 57 Action list: ['m u_1 w', 'dl 8 1 7 1', 'm u_3 n', 'dl 8 2 7 1', 'm u_4 n', 'dl 7 1 7 0', 'm u_5 n', 'dl 8 3 7 1']
# Super secret. Turn: 58 Action list: []
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 59 Action list: ['r 8 4', 'm u_1 n', 'dl 7 1 7 0', 'm u_3 w', 'dl 8 1 7 1', 'bcity u_4', 'm u_5 n', 'dl 8 2 7 1']
# [WARN] (match_wiE36PyPlvkT) - turn 59; Unit u_1 collided when trying to move n to (7, 0)
# [WARN] (match_wiE36PyPlvkT) - turn 59; Unit u_3 collided when trying to move w to (7, 1)
# [WARN] (match_wiE36PyPlvkT) - turn 59; Unit u_5 collided when trying to move n to (8, 1)
# Super secret. Turn: 60 Action list: ['bw 7 6', 'bw 7 0', 'm u_1 w', 'dl 7 1 6 1', 'm u_3 w', 'dl 8 1 7 1', 'm u_4 w', 'dl 7 0 6 0', 'm u_5 n', 'dl 8 2 7 1']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (7, 0) but unit cap reached. Build more CityTiles!; turn 60; cmd: bw 7 0
# Super secret. Turn: 61 Action list: ['r 7 0', 'm u_6 n', 'dl 7 6 7 1']
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 62 Action list: ['bcity u_1', 'm u_3 w', 'dl 7 1 6 1', 'm u_4 c', 'dl 6 0 6 0', 'm u_5 w', 'dl 8 1 7 1', 'm u_6 n', 'dl 7 5 7 1']
# [WARN] (match_wiE36PyPlvkT) - turn 62; Unit u_3 collided when trying to move w to (6, 1)
# [WARN] (match_wiE36PyPlvkT) - turn 62; Unit u_5 collided when trying to move w to (7, 1)
# Super secret. Turn: 63 Action list: ['bw 6 1', 'm u_1 n', 'dl 6 1 6 0', 'm u_3 e', 'dl 7 1 8 1', 'm u_4 e', 'dl 6 0 8 0', 'm u_5 w', 'dl 8 1 7 1', 'm u_6 n', 'dl 7 4 7 1']
# Super secret. Turn: 64 Action list: ['m u_4 w', 'dl 7 0 6 0', 'dx 6 0']
# [WARN] (match_wiE36PyPlvkT) - turn 64; Unit u_4 collided when trying to move w to (6, 0)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 65 Action list: ['r 7 4', 'm u_1 c', 'dl 6 0 6 0', 'bcity u_3', 'dx 6 0', 'm u_5 e', 'dl 7 1 8 1', 'm u_6 n', 'dl 7 3 7 1', 'dx 6 0']
# [WARN] (match_wiE36PyPlvkT) - turn 65; Unit u_5 collided when trying to move e to (8, 1)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 66 Action list: ['bw 7 5', 'bw 8 1', 'm u_1 e', 'dl 6 0 8 0', 'm u_3 n', 'dl 8 1 6 0', 'm u_4 w', 'dl 7 0 6 0', 'bcity u_5', 'dx 6 0']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (8, 1) but unit cap reached. Build more CityTiles!; turn 66; cmd: bw 8 1
# Super secret. Turn: 67 Action list: ['bw 7 1', 'bw 8 1', 'm u_1 w', 'dl 7 0 6 0', 'm u_5 n', 'dl 7 1 6 0', 'm u_6 n', 'dl 7 2 6 0', 'dx 6 0', 'm u_8 n', 'dl 7 5 6 0']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (8, 1) but unit cap reached. Build more CityTiles!; turn 67; cmd: bw 8 1
# [WARN] (match_wiE36PyPlvkT) - turn 67; Unit u_1 collided when trying to move w to (6, 0)
# Super secret. Turn: 68 Action list: ['r 8 1', 'm u_1 w', 'dl 7 0 6 0', 'm u_3 w', 'dl 8 0 6 0', 'dx 6 0', 'dx 6 0', 'm u_6 n', 'dl 7 1 6 0', 'dx 6 0', 'm u_8 n', 'dl 7 4 6 0', 'm u_9 n', 'dl 7 1 6 0']
# [WARN] (match_wiE36PyPlvkT) - turn 68; Unit u_1 collided when trying to move w to (6, 0)
# Super secret. Turn: 69 Action list: ['r 8 4', 'm u_1 w', 'dl 7 0 6 0', 'dx 6 0', 'm u_4 e', 'dl 6 0 8 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0']
# Super secret. Turn: 70 Action list: ['r 7 6', 'm u_3 w', 'dl 7 0 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'm u_8 n', 'dl 7 3 6 0', 'dx 6 0']
# [WARN] (match_wiE36PyPlvkT) - turn 70; Unit u_3 collided when trying to move w to (6, 0)
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_5 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_6 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_7 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_9 Apparently I can't find any resources.
# Super secret. Turn: 71 Action list: ['bw 7 0']
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_5 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_6 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_7 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_9 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Super secret. Turn: 72 Action list: []
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_5 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_6 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_7 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_9 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Super secret. Turn: 73 Action list: ['r 6 1']
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_5 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_6 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_7 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_9 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Super secret. Turn: 74 Action list: []
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_5 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_6 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_7 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_9 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Super secret. Turn: 75 Action list: ['r 7 4']
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_5 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_6 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_7 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_9 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Super secret. Turn: 76 Action list: ['r 7 5']
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_5 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_6 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_7 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_9 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Super secret. Turn: 77 Action list: ['r 7 1']
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_5 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_6 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_7 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_9 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Super secret. Turn: 78 Action list: ['r 8 1']
# Well.. Shit. I'm unit, u_1 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_3 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_4 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_5 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_6 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_7 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_9 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Super secret. Turn: 79 Action list: ['r 8 4']
# Super secret. Turn: 80 Action list: ['r 7 6', 'm u_1 c', 'dl 6 0 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0']
# Super secret. Turn: 81 Action list: ['r 7 0', 'm u_1 e', 'dl 6 0 8 0', 'm u_3 w', 'dl 7 0 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0']
# Super secret. Turn: 82 Action list: ['m u_1 w', 'dl 7 0 5 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'm u_7 w', 'dl 6 1 5 1', 'dx 6 0', 'dx 6 0']
# [WARN] (match_wiE36PyPlvkT) - turn 82; Unit u_1 collided when trying to move w to (6, 0)
# Super secret. Turn: 83 Action list: ['r 6 1', 'm u_1 w', 'dl 7 0 5 0', 'm u_3 w', 'dl 6 0 5 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0']
# Super secret. Turn: 84 Action list: ['m u_4 w', 'dl 7 0 5 0', 'dx 6 0', 'dx 6 0', 'm u_7 s', 'dl 5 1 5 2', 'dx 6 0', 'dx 6 0']
# [WARN] (match_wiE36PyPlvkT) - turn 84; Unit u_4 collided when trying to move w to (6, 0)
# Super secret. Turn: 85 Action list: ['r 7 4', 'm u_1 w', 'dl 6 0 5 0', 'm u_3 e', 'dl 5 0 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'dx 6 0']
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 86 Action list: ['r 7 5', 'm u_4 w', 'dl 7 0 5 0', 'dx 6 0', 'dx 6 0', 'bcity u_7', 'dx 6 0', 'dx 6 0']
# [WARN] (match_wiE36PyPlvkT) - turn 86; Unit u_4 collided when trying to move w to (6, 0)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 87 Action list: ['bw 7 1', 'bw 5 2', 'm u_1 e', 'dl 5 0 6 0', 'bcity u_3', 'dx 6 0', 'dx 6 0', 'dx 6 0', 'm u_7 n', 'dl 5 2 5 1', 'dx 6 0', 'dx 6 0']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (5, 2) but unit cap reached. Build more CityTiles!; turn 87; cmd: bw 5 2
# [WARN] (match_wiE36PyPlvkT) - turn 87; Unit u_1 collided when trying to move e to (6, 0)
# Super secret. Turn: 88 Action list: ['bw 8 1', 'bw 6 0', 'bw 5 2', 'm u_1 w', 'dl 5 0 3 0', 'm u_3 w', 'dl 6 0 5 0', 'm u_4 w', 'dl 7 0 5 0', 'm u_5 w', 'dl 7 0 5 0', 'm u_6 w', 'dl 7 0 5 0', 'm u_9 w', 'dl 7 0 5 0', 'm u_10 w', 'dl 7 0 5 0', 'm u_11 w', 'dl 7 1 5 1']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (6, 0) but unit cap reached. Build more CityTiles!; turn 88; cmd: bw 6 0
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (5, 2) but unit cap reached. Build more CityTiles!; turn 88; cmd: bw 5 2
# Super secret. Turn: 89 Action list: ['r 8 4', 'r 6 0', 'r 5 2', 'm u_4 w', 'dl 6 0 5 0', 'dx 5 0', 'dx 5 0', 'm u_7 w', 'dl 5 1 3 1', 'dx 5 0', 'dx 5 0', 'm u_11 w', 'dl 6 1 5 1', 'm u_12 w', 'dl 8 1 5 1']
# [WARN] (match_wiE36PyPlvkT) - turn 89; Unit u_4 collided when trying to move w to (5, 0)
# Super secret. Turn: 90 Action list: ['r 7 6', 'm u_1 w', 'dl 4 0 3 0', 'm u_3 w', 'dl 5 0 3 0', 'm u_4 w', 'dl 6 0 5 0', 'dx 5 0', 'dx 5 0', 'dx 5 0', 'dx 5 0', 'm u_12 w', 'dl 7 1 5 1']
# Super secret. Turn: 91 Action list: ['r 7 0', 'm u_5 w', 'dl 6 0 4 0', 'dx 5 0', 'm u_7 w', 'dl 4 1 3 1', 'dx 5 0', 'dx 5 0', 'm u_11 w', 'dl 5 1 4 1', 'm u_12 w', 'dl 6 1 4 1']
# [WARN] (match_wiE36PyPlvkT) - turn 91; Unit u_5 collided when trying to move w to (5, 0)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 92 Action list: ['bcity u_1', 'm u_3 w', 'dl 4 0 3 0', 'm u_4 w', 'dl 5 0 4 0', 'm u_5 w', 'dl 6 0 4 0', 'dx 5 0', 'dx 5 0', 'dx 5 0']
# [WARN] (match_wiE36PyPlvkT) - turn 92; Unit u_3 collided when trying to move w to (3, 0)
# [WARN] (match_wiE36PyPlvkT) - turn 92; Unit u_4 collided when trying to move w to (4, 0)
# [WARN] (match_wiE36PyPlvkT) - turn 92; Unit u_5 collided when trying to move w to (5, 0)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 93 Action list: ['bw 6 1', 'bw 3 0', 'm u_1 e', 'dl 3 0 4 0', 'm u_3 e', 'dl 4 0 5 0', 'dx 4 0', 'dx 5 0', 'dx 5 0', 'bcity u_7', 'dx 5 0', 'dx 5 0', 'm u_11 w', 'dl 4 1 3 1', 'm u_12 w', 'dl 5 1 4 1']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (3, 0) but unit cap reached. Build more CityTiles!; turn 93; cmd: bw 3 0
# [WARN] (match_wiE36PyPlvkT) - turn 93; Unit u_3 collided when trying to move e to (5, 0)
# [WARN] (match_wiE36PyPlvkT) - turn 93; Unit u_1 collided when trying to move e to (4, 0)
# [WARN] (match_wiE36PyPlvkT) - turn 93; Unit u_11 collided when trying to move w to (3, 1)
# [WARN] (match_wiE36PyPlvkT) - turn 93; Unit u_12 collided when trying to move w to (4, 1)
# Super secret. Turn: 94 Action list: ['bw 3 0', 'bw 3 1', 'm u_1 e', 'dl 3 0 4 0', 'm u_3 e', 'dl 4 0 5 0', 'dx 4 0', 'dx 5 0', 'dx 5 0', 'm u_7 e', 'dl 3 1 4 1', 'dx 5 0', 'dx 5 0', 'm u_11 e', 'dl 4 1 5 1', 'dx 4 1', 'dx 5 1']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (3, 1) but unit cap reached. Build more CityTiles!; turn 94; cmd: bw 3 1
# [WARN] (match_wiE36PyPlvkT) - turn 94; Unit u_3 collided when trying to move e to (5, 0)
# [WARN] (match_wiE36PyPlvkT) - turn 94; Unit u_1 collided when trying to move e to (4, 0)
# [WARN] (match_wiE36PyPlvkT) - turn 94; Unit u_11 collided when trying to move e to (5, 1)
# [WARN] (match_wiE36PyPlvkT) - turn 94; Unit u_7 collided when trying to move e to (4, 1)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 95 Action list: ['r 7 4', 'r 3 1', 'm u_1 e', 'dl 3 0 4 0', 'm u_3 e', 'dl 4 0 5 0', 'bcity u_4', 'dx 5 0', 'dx 5 0', 'm u_7 e', 'dl 3 1 4 1', 'dx 5 0', 'dx 5 0', 'm u_11 e', 'dl 4 1 5 1', 'dx 4 1', 'dx 5 1', 'dx 4 0']
# [WARN] (match_wiE36PyPlvkT) - turn 95; Unit u_3 collided when trying to move e to (5, 0)
# [WARN] (match_wiE36PyPlvkT) - turn 95; Unit u_1 collided when trying to move e to (4, 0)
# [WARN] (match_wiE36PyPlvkT) - turn 95; Unit u_11 collided when trying to move e to (5, 1)
# [WARN] (match_wiE36PyPlvkT) - turn 95; Unit u_7 collided when trying to move e to (4, 1)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 96 Action list: ['bw 7 5', 'bw 5 0', 'm u_1 e', 'dl 3 0 4 0', 'm u_3 w', 'dl 4 0 2 0', 'dx 4 0', 'm u_5 w', 'dl 6 0 4 0', 'm u_6 w', 'dl 6 0 4 0', 'm u_7 e', 'dl 3 1 4 1', 'm u_9 w', 'dl 6 0 4 0', 'm u_10 w', 'dl 6 0 4 0', 'm u_11 e', 'dl 4 1 5 1', 'bcity u_12', 'dx 5 1', 'dx 4 0']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (5, 0) but unit cap reached. Build more CityTiles!; turn 96; cmd: bw 5 0
# [WARN] (match_wiE36PyPlvkT) - turn 96; Unit u_11 collided when trying to move e to (5, 1)
# [WARN] (match_wiE36PyPlvkT) - turn 96; Unit u_7 collided when trying to move e to (4, 1)
# Super secret. Turn: 97 Action list: ['bw 7 1', 'bw 5 0', 'bw 5 1', 'm u_3 e', 'dl 3 0 4 0', 'dx 4 0', 'dx 4 0', 'dx 4 0', 'm u_7 e', 'dl 3 1 4 1', 'dx 4 0', 'dx 4 0', 'm u_11 s', 'dl 4 1 4 2', 'dx 4 1', 'm u_13 w', 'dl 6 1 4 1', 'dx 4 0', 'm u_15 n', 'dl 7 5 4 1']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (5, 0) but unit cap reached. Build more CityTiles!; turn 97; cmd: bw 5 0
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (5, 1) but unit cap reached. Build more CityTiles!; turn 97; cmd: bw 5 1
# [WARN] (match_wiE36PyPlvkT) - turn 97; Unit u_3 collided when trying to move e to (4, 0)
# Super secret. Turn: 98 Action list: ['r 8 1', 'r 5 0', 'r 5 1', 'm u_1 c', 'dl 4 0 4 0', 'dx 4 0', 'dx 4 0', 'dx 4 0', 'dx 4 0', 'dx 4 0', 'dx 4 0', 'm u_12 w', 'dl 5 1 4 1', 'dx 4 1', 'dx 4 0', 'm u_15 n', 'dl 7 4 4 1', 'm u_16 w', 'dl 7 1 4 1']
# [WARN] (match_wiE36PyPlvkT) - turn 98; Unit u_12 collided when trying to move w to (4, 1)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 99 Action list: ['r 8 4', 'r 6 0', 'r 5 2', 'm u_1 w', 'dl 4 0 2 0', 'm u_3 e', 'dl 3 0 4 0', 'dx 4 0', 'dx 4 0', 'dx 4 0', 'm u_7 c', 'dl 4 1 4 1', 'dx 4 0', 'dx 4 0', 'bcity u_11', 'dx 4 1', 'dx 4 1', 'dx 4 0', 'm u_16 w', 'dl 6 1 4 1']
# Super secret. Turn: 100 Action list: ['bw 7 6', 'bw 4 2', 'm u_1 e', 'dl 3 0 4 1', 'm u_4 s', 'dl 5 0 4 1', 'm u_5 s', 'dl 5 0 4 1', 'm u_6 s', 'dl 5 0 4 1', 'dx 4 0', 'm u_9 s', 'dl 5 0 4 1', 'm u_10 s', 'dl 5 0 4 1', 'm u_11 n', 'dl 4 2 4 1', 'dx 4 1', 'dx 4 1', 'dx 4 0', 'm u_15 n', 'dl 7 3 4 1', 'dx 4 1']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (4, 2) but unit cap reached. Build more CityTiles!; turn 100; cmd: bw 4 2
# [WARN] (match_wiE36PyPlvkT) - turn 100; Unit u_1 collided when trying to move e to (4, 0)
# [WARN] (match_wiE36PyPlvkT) - turn 100; Unit u_11 collided when trying to move n to (4, 1)
# Super secret. Turn: 101 Action list: ['r 7 0', 'r 4 2', 'm u_1 e', 'dl 3 0 4 1', 'm u_3 s', 'dl 4 0 4 1', 'dx 4 1', 'dx 4 1', 'dx 4 1', 'dx 4 0', 'dx 4 1', 'dx 4 1', 'dx 4 1', 'dx 4 1', 'dx 4 1', 'dx 4 0', 'dx 4 1', 'm u_17 s', 'dl 7 6 6 11']
# [WARN] (match_wiE36PyPlvkT) - turn 101; Unit u_3 collided when trying to move s to (4, 1)
# [WARN] (match_wiE36PyPlvkT) - turn 101; Unit u_1 collided when trying to move e to (4, 0)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 102 Action list: ['m u_1 s', 'dl 3 0 3 11', 'm u_3 s', 'dl 4 0 3 11', 'm u_4 e', 'dl 5 1 6 11', 'm u_5 e', 'dl 5 1 6 11', 'm u_6 e', 'dl 5 1 6 11', 'bcity u_7', 'm u_9 e', 'dl 5 1 6 11', 'm u_10 e', 'dl 5 1 6 11', 'm u_11 s', 'dl 4 2 3 11', 'm u_12 e', 'dl 5 1 6 11', 'm u_13 e', 'dl 5 1 6 11', 'm u_14 s', 'dl 3 0 3 11', 'm u_15 s', 'dl 7 2 6 11', 'm u_16 e', 'dl 5 1 6 11']
# [WARN] (match_wiE36PyPlvkT) - turn 102; Unit u_3 collided when trying to move s to (4, 1)
# Super secret. Turn: 103 Action list: ['bw 6 1', 'bw 4 1', 'm u_1 s', 'dl 3 1 3 11', 'm u_3 s', 'dl 4 0 3 11', 'm u_4 s', 'dl 6 1 6 11', 'dx 6 2', 'dx 6 2', 'm u_7 s', 'dl 4 1 3 11', 'dx 6 2', 'dx 6 2', 'dx 6 2', 'dx 6 2', 'dx 3 2', 'dx 6 2', 'm u_17 s', 'dl 7 7 6 11']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (4, 1) but unit cap reached. Build more CityTiles!; turn 103; cmd: bw 4 1
# Super secret. Turn: 104 Action list: ['r 4 1', 'r 3 0', 'm u_3 s', 'dl 4 1 3 11', 'm u_5 s', 'dl 6 1 6 11', 'dx 6 2', 'm u_7 s', 'dl 4 2 3 11', 'dx 6 2', 'dx 6 2', 'm u_11 s', 'dl 4 3 3 11', 'dx 6 2', 'dx 6 2', 'm u_14 s', 'dl 3 1 3 11', 'm u_15 s', 'dl 7 3 6 11', 'dx 6 2', 'dx 6 2']
# [WARN] (match_wiE36PyPlvkT) - turn 104; Unit u_5 collided when trying to move s to (6, 2)
# [WARN] (match_wiE36PyPlvkT) - turn 104; Unit u_14 collided when trying to move s to (3, 2)
# Super secret. Turn: 105 Action list: ['r 7 4', 'r 3 1', 'm u_1 s', 'dl 3 2 3 11', 'm u_3 s', 'dl 4 2 3 11', 'm u_4 s', 'dl 6 2 6 11', 'm u_5 s', 'dl 6 1 6 11', 'dx 6 2', 'dx 6 2', 'dx 6 2', 'dx 6 2', 'dx 6 2', 'm u_14 s', 'dl 3 1 3 11', 'm u_15 s', 'dl 7 4 6 11', 'dx 6 2', 'm u_17 s', 'dl 7 8 6 11', 'dx 6 2']
# [WARN] (match_wiE36PyPlvkT) - turn 105; Unit u_3 collided when trying to move s to (4, 3)
# Super secret. Turn: 106 Action list: ['r 7 5', 'm u_3 s', 'dl 4 2 0 7', 'm u_6 s', 'dl 6 1 6 11', 'm u_7 s', 'dl 4 3 0 7', 'dx 6 2', 'dx 6 2', 'm u_11 s', 'dl 4 4 0 7', 'dx 6 2', 'dx 6 2', 'm u_15 s', 'dl 7 5 6 11', 'dx 6 2', 'dx 6 2']
# [WARN] (match_wiE36PyPlvkT) - turn 106; Unit u_6 collided when trying to move s to (6, 2)
# Super secret. Turn: 107 Action list: ['r 7 1', 'm u_1 s', 'dl 3 3 0 7', 'm u_4 s', 'dl 6 3 6 11', 'm u_5 s', 'dl 6 2 6 11', 'm u_6 s', 'dl 6 1 6 11', 'dx 6 2', 'dx 6 2', 'dx 6 2', 'dx 6 2', 'm u_14 s', 'dl 3 2 0 7', 'm u_15 s', 'dl 7 6 6 11', 'dx 6 2', 'm u_17 s', 'dl 7 9 6 11', 'dx 6 2']
# Super secret. Turn: 108 Action list: ['r 8 1', 'r 5 0', 'r 5 1', 'm u_3 s', 'dl 4 3 0 7', 'm u_7 s', 'dl 4 4 0 7', 'm u_9 s', 'dl 6 1 6 11', 'dx 6 2', 'm u_11 s', 'dl 4 5 0 7', 'dx 6 2', 'dx 6 2', 'dx 6 2', 'dx 6 2']
# [WARN] (match_wiE36PyPlvkT) - turn 108; Unit u_9 collided when trying to move s to (6, 2)
# Super secret. Turn: 109 Action list: ['r 8 4', 'r 6 0', 'r 5 2', 'm u_1 s', 'dl 3 4 0 7', 'm u_4 s', 'dl 6 4 6 11', 'm u_5 s', 'dl 6 3 6 11', 'm u_6 s', 'dl 6 2 6 11', 'm u_9 s', 'dl 6 1 6 11', 'dx 6 2', 'dx 6 2', 'dx 6 2', 'm u_14 s', 'dl 3 3 0 7', 'm u_15 s', 'dl 7 7 6 11', 'dx 6 2', 'm u_17 s', 'dl 7 10 6 11', 'dx 6 2']
# Super secret. Turn: 110 Action list: ['r 7 6', 'm u_3 s', 'dl 4 4 0 7', 'm u_7 s', 'dl 4 5 0 7', 'm u_10 s', 'dl 6 1 6 11', 'm u_11 s', 'dl 4 6 0 7', 'dx 6 2', 'dx 6 2', 'dx 6 2', 'dx 6 2']
# [WARN] (match_wiE36PyPlvkT) - turn 110; Unit u_10 collided when trying to move s to (6, 2)
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_12 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_13 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_16 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_18 Apparently I can't find any resources.
# Super secret. Turn: 111 Action list: ['bw 7 0', 'bw 4 2']
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_12 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_13 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_16 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_18 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_19 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_20 Apparently I can't find any resources.
# Super secret. Turn: 112 Action list: []
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_12 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_13 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_16 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_18 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_19 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_20 Apparently I can't find any resources.
# Super secret. Turn: 113 Action list: ['bw 6 1']
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_12 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_13 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_16 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_18 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_19 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_20 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_21 Apparently I can't find any resources.
# Super secret. Turn: 114 Action list: ['bw 4 1', 'bw 3 0']
# Well.. Shit. I'm unit, u_10 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_12 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_13 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_16 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_18 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_19 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_20 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_21 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_22 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_23 Apparently I can't find any resources.
# Super secret. Turn: 115 Action list: ['bw 7 4', 'bw 3 1']
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_24 Apparently I can't find any resources.
# Super secret. Turn: 116 Action list: ['bw 7 5']
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_24 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_26 Apparently I can't find any resources.
# Super secret. Turn: 117 Action list: []
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Super secret. Turn: 118 Action list: []
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Super secret. Turn: 119 Action list: []
# Super secret. Turn: 120 Action list: ['m u_17 w', 'dl 7 11 6 11']
# Super secret. Turn: 121 Action list: []
# Super secret. Turn: 122 Action list: ['m u_17 n', 'dl 6 11 6 10']
# Super secret. Turn: 123 Action list: []
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 124 Action list: ['bcity u_17']
# Super secret. Turn: 125 Action list: ['r 6 10', 'm u_17 s', 'dl 6 10 6 11']
# Super secret. Turn: 126 Action list: []
# Super secret. Turn: 127 Action list: ['m u_17 c', 'dl 6 11 6 11']
# Super secret. Turn: 128 Action list: ['m u_17 c', 'dl 6 11 6 11']
# Super secret. Turn: 129 Action list: ['m u_17 c', 'dl 6 11 6 11']
# Super secret. Turn: 130 Action list: ['m u_17 w', 'dl 6 11 5 11']
# Super secret. Turn: 131 Action list: []
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 132 Action list: ['bcity u_17']
# Super secret. Turn: 133 Action list: ['bw 5 11', 'm u_17 e', 'dl 5 11 6 11']
# Super secret. Turn: 134 Action list: ['m u_27 e', 'dl 5 11 6 11']
# [WARN] (match_wiE36PyPlvkT) - turn 134; Unit u_27 collided when trying to move e to (6, 11)
# Super secret. Turn: 135 Action list: ['r 6 10', 'm u_17 c', 'dl 6 11 6 11', 'dx 6 11']
# Super secret. Turn: 136 Action list: ['m u_17 c', 'dl 6 11 6 11', 'dx 6 11']
# Super secret. Turn: 137 Action list: ['m u_17 c', 'dl 6 11 6 11', 'dx 6 11']
# Super secret. Turn: 138 Action list: ['m u_17 e', 'dl 6 11 7 11', 'm u_27 e', 'dl 5 11 6 11']
# Super secret. Turn: 139 Action list: []
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 140 Action list: ['bcity u_17', 'm u_27 c', 'dl 6 11 6 11']
# Super secret. Turn: 141 Action list: ['bw 7 11', 'm u_17 w', 'dl 7 11 6 11', 'dx 6 11']
# [WARN] (match_wiE36PyPlvkT) - turn 141; Unit u_17 collided when trying to move w to (6, 11)
# Super secret. Turn: 142 Action list: ['m u_17 w', 'dl 7 11 6 11', 'dx 6 11', 'dx 6 11']
# [WARN] (match_wiE36PyPlvkT) - turn 142; Unit u_17 collided when trying to move w to (6, 11)
# Super secret. Turn: 143 Action list: ['r 5 11', 'm u_17 s', 'dl 7 11 5 12', 'm u_27 s', 'dl 6 11 5 12', 'dx 7 12']
# Super secret. Turn: 144 Action list: ['m u_28 s', 'dl 7 11 5 12']
# [WARN] (match_wiE36PyPlvkT) - turn 144; Unit u_28 collided when trying to move s to (7, 12)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 145 Action list: ['r 6 10', 'm u_17 w', 'dl 7 12 5 12', 'bcity u_27', 'm u_28 s', 'dl 7 11 5 12']
# [WARN] (match_wiE36PyPlvkT) - turn 145; Unit u_17 collided when trying to move w to (6, 12)
# [WARN] (match_wiE36PyPlvkT) - turn 145; Unit u_28 collided when trying to move s to (7, 12)
# Super secret. Turn: 146 Action list: ['bw 6 12', 'm u_17 w', 'dl 7 12 5 12', 'm u_27 w', 'dl 6 12 5 12', 'm u_28 s', 'dl 7 11 5 12']
# Super secret. Turn: 147 Action list: ['m u_17 w', 'dl 6 12 5 12', 'dx 5 12']
# [WARN] (match_wiE36PyPlvkT) - turn 147; Unit u_17 collided when trying to move w to (5, 12)
# Super secret. Turn: 148 Action list: ['m u_17 w', 'dl 6 12 5 12', 'm u_27 n', 'dl 5 12 5 10', 'm u_28 w', 'dl 7 12 5 12', 'dx 5 12']
# Super secret. Turn: 149 Action list: ['m u_27 s', 'dl 5 11 5 12', 'dx 5 12', 'dx 5 12']
# [WARN] (match_wiE36PyPlvkT) - turn 149; Unit u_27 collided when trying to move s to (5, 12)
# Super secret. Turn: 150 Action list: ['m u_17 n', 'dl 5 12 5 10', 'm u_27 s', 'dl 5 11 5 12', 'dx 5 12', 'dx 5 12']
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_28 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_29 Apparently I can't find any resources.
# Super secret. Turn: 151 Action list: ['r 7 11']
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_28 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_29 Apparently I can't find any resources.
# Super secret. Turn: 152 Action list: []
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_28 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_29 Apparently I can't find any resources.
# Super secret. Turn: 153 Action list: ['r 5 11']
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_28 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_29 Apparently I can't find any resources.
# Super secret. Turn: 154 Action list: []
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_28 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_29 Apparently I can't find any resources.
# Super secret. Turn: 155 Action list: []
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_28 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_29 Apparently I can't find any resources.
# Super secret. Turn: 156 Action list: ['r 6 12']
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# Super secret. Turn: 157 Action list: []
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# Super secret. Turn: 158 Action list: []
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# Super secret. Turn: 159 Action list: []
# Super secret. Turn: 160 Action list: ['m u_17 s', 'dl 5 11 5 12', 'dx 5 12']
# [WARN] (match_wiE36PyPlvkT) - turn 160; Unit u_17 collided when trying to move s to (5, 12)
# Super secret. Turn: 161 Action list: ['m u_17 s', 'dl 5 11 5 12', 'm u_27 e', 'dl 5 12 6 12']
# Super secret. Turn: 162 Action list: []
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 163 Action list: ['r 5 11', 'm u_17 w', 'dl 5 12 4 12', 'bcity u_27']
# Super secret. Turn: 164 Action list: ['r 6 12', 'm u_27 w', 'dl 6 12 4 12']
# Super secret. Turn: 165 Action list: ['m u_17 n', 'dl 4 12 4 11']
# Super secret. Turn: 166 Action list: ['m u_27 w', 'dl 5 12 4 12']
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 167 Action list: ['bcity u_17']
# Super secret. Turn: 168 Action list: ['bw 4 11', 'm u_17 w', 'dl 4 11 3 11', 'm u_27 e', 'dl 4 12 5 12']
# Super secret. Turn: 169 Action list: ['m u_30 w', 'dl 4 11 3 11']
# [WARN] (match_wiE36PyPlvkT) - turn 169; Unit u_30 collided when trying to move w to (3, 11)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 170 Action list: ['m u_17 c', 'dl 3 11 3 11', 'bcity u_27', 'dx 3 11']
# Super secret. Turn: 171 Action list: ['bw 5 12', 'm u_17 n', 'dl 3 11 3 10', 'm u_27 w', 'dl 5 12 4 12', 'm u_30 w', 'dl 4 11 3 11']
# Super secret. Turn: 172 Action list: ['m u_31 w', 'dl 5 12 4 12']
# [WARN] (match_wiE36PyPlvkT) - turn 172; Unit u_31 collided when trying to move w to (4, 12)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 173 Action list: ['r 5 11', 'bcity u_17', 'm u_27 n', 'dl 4 12 4 10', 'm u_30 c', 'dl 3 11 3 11', 'm u_31 w', 'dl 5 12 4 12']
# Super secret. Turn: 174 Action list: ['bw 6 12', 'bw 3 10', 'm u_17 s', 'dl 3 10 3 11', 'dx 3 11', 'm u_30 w', 'dl 3 11 2 11']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (3, 10) but unit cap reached. Build more CityTiles!; turn 174; cmd: bw 3 10
# Super secret. Turn: 175 Action list: ['r 3 10', 'm u_27 w', 'dl 4 11 3 11', 'm u_31 n', 'dl 4 12 4 10', 'm u_32 w', 'dl 6 12 4 12']
# [WARN] (match_wiE36PyPlvkT) - turn 175; Unit u_27 collided when trying to move w to (3, 11)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 176 Action list: ['m u_17 c', 'dl 3 11 3 11', 'dx 3 11', 'bcity u_30', 'dx 3 11', 'm u_32 w', 'dl 5 12 4 12']
# Super secret. Turn: 177 Action list: ['bw 2 11', 'm u_17 n', 'dl 3 11 3 9', 'm u_27 w', 'dl 4 11 3 11', 'dx 3 11', 'dx 3 11']
# Super secret. Turn: 178 Action list: ['r 4 11', 'm u_17 s', 'dl 3 10 3 11', 'dx 3 11', 'dx 3 11', 'm u_32 n', 'dl 4 12 4 10', 'dx 3 11']
# [WARN] (match_wiE36PyPlvkT) - turn 178; Unit u_17 collided when trying to move s to (3, 11)
# Super secret. Turn: 179 Action list: ['m u_17 s', 'dl 3 10 3 12', 'm u_27 s', 'dl 3 11 3 12', 'dx 3 11', 'm u_31 s', 'dl 4 11 3 12', 'dx 4 12', 'dx 3 11']
# Super secret. Turn: 180 Action list: ['m u_30 e', 'dl 2 11 3 12', 'm u_32 s', 'dl 4 11 3 12', 'dx 3 11']
# [WARN] (match_wiE36PyPlvkT) - turn 180; Unit u_30 collided when trying to move e to (3, 11)
# [WARN] (match_wiE36PyPlvkT) - turn 180; Unit u_32 collided when trying to move s to (4, 12)
# Super secret. Turn: 181 Action list: ['r 5 12', 'm u_17 s', 'dl 3 11 3 12', 'm u_27 n', 'dl 3 12 3 11', 'dx 3 11', 'dx 3 12', 'm u_32 s', 'dl 4 11 3 12', 'dx 3 11']
# [WARN] (match_wiE36PyPlvkT) - turn 181; Unit u_32 collided when trying to move s to (4, 12)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 182 Action list: ['m u_30 e', 'dl 2 11 3 12', 'bcity u_31', 'm u_32 s', 'dl 4 11 3 12', 'dx 3 11']
# [WARN] (match_wiE36PyPlvkT) - turn 182; Unit u_30 collided when trying to move e to (3, 11)
# [WARN] (match_wiE36PyPlvkT) - turn 182; Unit u_32 collided when trying to move s to (4, 12)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 183 Action list: ['bw 5 11', 'bw 4 12', 'm u_17 n', 'dl 3 12 3 11', 'bcity u_27', 'dx 3 11', 'm u_31 w', 'dl 4 12 3 12', 'm u_32 s', 'dl 4 11 3 12', 'dx 3 11']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (4, 12) but unit cap reached. Build more CityTiles!; turn 183; cmd: bw 4 12
# [WARN] (match_wiE36PyPlvkT) - turn 183; Unit u_17 collided when trying to move n to (3, 11)
# [WARN] (match_wiE36PyPlvkT) - turn 183; Unit u_31 collided when trying to move w to (3, 12)
# Super secret. Turn: 184 Action list: ['bw 3 11', 'bw 6 12', 'bw 4 12', 'm u_17 w', 'dl 3 12 2 12', 'm u_27 s', 'dl 3 11 3 12', 'm u_30 e', 'dl 2 11 3 12', 'dx 3 12', 'dx 3 12', 'm u_33 e', 'dl 2 11 3 12', 'm u_34 s', 'dl 5 11 5 13']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (6, 12) but unit cap reached. Build more CityTiles!; turn 184; cmd: bw 6 12
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (4, 12) but unit cap reached. Build more CityTiles!; turn 184; cmd: bw 4 12
# Super secret. Turn: 185 Action list: ['r 3 10', 'r 6 12', 'r 4 12', 'm u_30 s', 'dl 3 11 3 12', 'dx 3 12', 'dx 3 12', 'dx 3 12', 'm u_34 s', 'dl 5 12 5 13', 'dx 3 12']
# [WARN] (match_wiE36PyPlvkT) - turn 185; Unit u_30 collided when trying to move s to (3, 12)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 186 Action list: ['bcity u_17', 'm u_27 s', 'dl 3 12 3 13', 'm u_30 s', 'dl 3 11 3 13', 'm u_31 s', 'dl 4 12 4 13', 'dx 4 13', 'dx 3 12', 'dx 3 12']
# Super secret. Turn: 187 Action list: ['bw 2 11', 'bw 2 12', 'm u_17 e', 'dl 2 12 3 13', 'm u_32 s', 'dl 4 12 4 13', 'dx 3 12', 'm u_34 c', 'dl 5 13 5 13', 'dx 3 12']
# [WARN] (match_wiE36PyPlvkT) - Agent 0 tried to build unit on tile (2, 12) but unit cap reached. Build more CityTiles!; turn 187; cmd: bw 2 12
# [WARN] (match_wiE36PyPlvkT) - turn 187; Unit u_17 collided when trying to move e to (3, 12)
# [WARN] (match_wiE36PyPlvkT) - turn 187; Unit u_32 collided when trying to move s to (4, 13)
# Super secret. Turn: 188 Action list: ['r 4 11', 'r 2 12', 'm u_17 e', 'dl 2 12 3 13', 'dx 3 12', 'm u_30 s', 'dl 3 12 3 13', 'm u_31 s', 'dl 4 13 4 14', 'm u_32 s', 'dl 4 12 4 13', 'dx 3 12', 'm u_34 e', 'dl 5 13 6 13', 'dx 3 12', 'm u_36 e', 'dl 2 11 3 13']
# [WARN] (match_wiE36PyPlvkT) - turn 188; Unit u_30 collided when trying to move s to (3, 13)
# [WARN] (match_wiE36PyPlvkT) - turn 188; Unit u_17 collided when trying to move e to (3, 12)
# Super secret. Turn: 189 Action list: ['m u_17 e', 'dl 2 12 3 13', 'dx 3 12', 'm u_30 s', 'dl 3 12 3 13', 'dx 3 12', 'dx 3 12', 'dx 3 12']
# [WARN] (match_wiE36PyPlvkT) - turn 189; Unit u_30 collided when trying to move s to (3, 13)
# [WARN] (match_wiE36PyPlvkT) - turn 189; Unit u_17 collided when trying to move e to (3, 12)
# I'm gonna build a city because I have full inventory + I can build!
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 190 Action list: ['m u_17 e', 'dl 2 12 3 13', 'dx 3 12', 'm u_30 s', 'dl 3 12 3 13', 'bcity u_31', 'm u_32 s', 'dl 4 13 4 14', 'dx 3 12', 'bcity u_34', 'dx 3 12', 'dx 3 12']
# [WARN] (match_wiE36PyPlvkT) - turn 190; Unit u_30 collided when trying to move s to (3, 13)
# [WARN] (match_wiE36PyPlvkT) - turn 190; Unit u_17 collided when trying to move e to (3, 12)
# [WARN] (match_wiE36PyPlvkT) - turn 190; Unit u_32 collided when trying to move s to (4, 14)
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_33 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_34 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_35 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_36 Apparently I can't find any resources.
# Super secret. Turn: 191 Action list: ['bw 5 12', 'bw 6 13']
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_33 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_34 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_35 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_36 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_37 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_38 Apparently I can't find any resources.
# Super secret. Turn: 192 Action list: []
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_33 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_34 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_35 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_36 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_37 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_38 Apparently I can't find any resources.
# Super secret. Turn: 193 Action list: ['r 5 11']
# Well.. Shit. I'm unit, u_17 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# ...
# Well.. Shit. I'm unit, u_45 Apparently I can't find any resources.
# Super secret. Turn: 236 Action list: ['r 1 13']
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_39 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_40 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_41 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_42 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_43 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_44 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_45 Apparently I can't find any resources.
# Super secret. Turn: 237 Action list: []
# Well.. Shit. I'm unit, u_27 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_39 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_40 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_41 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_42 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_43 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_44 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_45 Apparently I can't find any resources.
# Super secret. Turn: 238 Action list: ['r 3 14']
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_44 Apparently I can't find any resources.
# Super secret. Turn: 239 Action list: []
# Super secret. Turn: 240 Action list: ['m u_30 c', 'dl 1 15 1 15', 'dx 1 15', 'm u_44 w', 'dl 3 15 1 15']
# [WARN] (match_wiE36PyPlvkT) - turn 240; Unit u_44 collided when trying to move w to (2, 15)
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 241 Action list: ['m u_30 n', 'dl 1 15 1 14', 'bcity u_32', 'm u_44 w', 'dl 3 15 1 15']
# [WARN] (match_wiE36PyPlvkT) - turn 241; Unit u_44 collided when trying to move w to (2, 15)
# Super secret. Turn: 242 Action list: ['r 2 15', 'm u_32 w', 'dl 2 15 1 15', 'm u_44 w', 'dl 3 15 1 15']
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 243 Action list: ['bcity u_30', 'm u_44 n', 'dl 2 15 0 7']
# Super secret. Turn: 244 Action list: ['r 1 14', 'm u_30 n', 'dl 1 14 0 7', 'm u_32 n', 'dl 1 15 0 7']
# Super secret. Turn: 245 Action list: ['m u_32 n', 'dl 1 14 0 7', 'm u_44 n', 'dl 2 14 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 245; Unit u_32 collided when trying to move n to (1, 13)
# Super secret. Turn: 246 Action list: ['m u_30 n', 'dl 1 13 0 7', 'm u_32 n', 'dl 1 14 0 7']
# Super secret. Turn: 247 Action list: ['m u_44 n', 'dl 2 13 0 7']
# Super secret. Turn: 248 Action list: ['m u_30 n', 'dl 1 12 0 7', 'm u_32 n', 'dl 1 13 0 7']
# Super secret. Turn: 249 Action list: ['m u_44 n', 'dl 2 12 0 7']
# Super secret. Turn: 250 Action list: ['m u_30 n', 'dl 1 11 0 7', 'm u_32 n', 'dl 1 12 0 7']
# Super secret. Turn: 251 Action list: ['m u_44 n', 'dl 2 11 0 7']
# Super secret. Turn: 252 Action list: ['r 2 15', 'm u_30 n', 'dl 1 10 0 7', 'm u_32 n', 'dl 1 11 0 7']
# Super secret. Turn: 253 Action list: ['m u_44 n', 'dl 2 10 0 7']
# Super secret. Turn: 254 Action list: ['r 1 14', 'm u_30 n', 'dl 1 9 0 7', 'm u_32 n', 'dl 1 10 0 7']
# Super secret. Turn: 255 Action list: ['m u_44 n', 'dl 2 9 0 7']
# Super secret. Turn: 256 Action list: ['m u_30 n', 'dl 1 8 0 7', 'm u_32 n', 'dl 1 9 0 7']
# Super secret. Turn: 257 Action list: ['m u_44 n', 'dl 2 8 0 7']
# Super secret. Turn: 258 Action list: ['m u_30 w', 'dl 1 7 0 7', 'm u_32 n', 'dl 1 8 0 7']
# Super secret. Turn: 259 Action list: ['m u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 259; Unit u_44 collided when trying to move w to (1, 7)
# Super secret. Turn: 260 Action list: ['m u_30 c', 'dl 0 7 0 7', 'dx 0 7', 'm u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 260; Unit u_44 collided when trying to move w to (1, 7)
# Super secret. Turn: 261 Action list: ['m u_30 c', 'dl 0 7 0 7', 'dx 0 7', 'm u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 261; Unit u_44 collided when trying to move w to (1, 7)
# Super secret. Turn: 262 Action list: ['r 2 15', 'm u_30 c', 'dl 0 7 0 7', 'dx 0 7', 'm u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 262; Unit u_44 collided when trying to move w to (1, 7)
# Super secret. Turn: 263 Action list: ['m u_30 c', 'dl 0 7 0 7', 'dx 0 7', 'm u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 263; Unit u_44 collided when trying to move w to (1, 7)
# Super secret. Turn: 264 Action list: ['r 1 14', 'm u_30 c', 'dl 0 7 0 7', 'dx 0 7', 'm u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 264; Unit u_44 collided when trying to move w to (1, 7)
# Super secret. Turn: 265 Action list: ['m u_30 c', 'dl 0 7 0 7', 'dx 0 7', 'm u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 265; Unit u_44 collided when trying to move w to (1, 7)
# Super secret. Turn: 266 Action list: ['m u_30 c', 'dl 0 7 0 7', 'dx 0 7', 'm u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 266; Unit u_44 collided when trying to move w to (1, 7)
# Super secret. Turn: 267 Action list: ['m u_30 c', 'dl 0 7 0 7', 'dx 0 7', 'm u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 267; Unit u_44 collided when trying to move w to (1, 7)
# Super secret. Turn: 268 Action list: ['m u_30 c', 'dl 0 7 0 7', 'dx 0 7', 'm u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 268; Unit u_44 collided when trying to move w to (1, 7)
# Super secret. Turn: 269 Action list: ['m u_30 c', 'dl 0 7 0 7', 'dx 0 7', 'm u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 269; Unit u_44 collided when trying to move w to (1, 7)
# Super secret. Turn: 270 Action list: ['m u_30 c', 'dl 0 7 0 7', 'dx 0 7', 'm u_44 w', 'dl 2 7 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 270; Unit u_44 collided when trying to move w to (1, 7)
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Super secret. Turn: 271 Action list: []
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Super secret. Turn: 272 Action list: ['r 2 15']
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Super secret. Turn: 273 Action list: []
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Super secret. Turn: 274 Action list: []
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Super secret. Turn: 275 Action list: []
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Super secret. Turn: 276 Action list: []
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Super secret. Turn: 277 Action list: []
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Super secret. Turn: 278 Action list: []
# Well.. Shit. I'm unit, u_30 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_32 Apparently I can't find any resources.
# Super secret. Turn: 279 Action list: []
# Super secret. Turn: 280 Action list: ['m u_30 c', 'dl 0 7 0 7', 'dx 0 7']
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 281 Action list: ['m u_30 n', 'dl 0 7 0 6', 'bcity u_32']
# Super secret. Turn: 282 Action list: ['r 1 7', 'm u_32 w', 'dl 1 7 0 7']
# I'm gonna build a city because I have full inventory + I can build!
# Super secret. Turn: 283 Action list: ['bcity u_30']
# Super secret. Turn: 284 Action list: ['r 0 6', 'm u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 284; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 285 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 285; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 286 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 286; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 287 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 287; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 288 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 288; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 289 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 289; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 290 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 290; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 291 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 291; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 292 Action list: ['r 1 7', 'm u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 292; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 293 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 293; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 294 Action list: ['r 0 6', 'm u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 294; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 295 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 295; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 296 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 296; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 297 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 297; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 298 Action list: ['m u_30 s', 'dl 0 6 0 7', 'dx 0 7']
# [WARN] (match_wiE36PyPlvkT) - turn 298; Unit u_30 collided when trying to move s to (0, 7)
# Super secret. Turn: 299 Action list: ['m u_30 e', 'dl 0 6 15 12', 'm u_32 e', 'dl 0 7 15 12']
# Super secret. Turn: 300 Action list: ['m u_32 e', 'dl 1 7 15 12']
# Super secret. Turn: 301 Action list: ['m u_30 e', 'dl 1 6 15 12']
# Super secret. Turn: 302 Action list: ['r 1 7', 'm u_32 e', 'dl 2 7 15 12']
# Super secret. Turn: 303 Action list: ['m u_30 e', 'dl 2 6 15 12']
# Super secret. Turn: 304 Action list: ['r 0 6', 'm u_32 e', 'dl 3 7 15 12']
# Super secret. Turn: 305 Action list: ['m u_30 e', 'dl 3 6 15 12']
# Super secret. Turn: 306 Action list: ['m u_32 e', 'dl 4 7 15 12']
# Super secret. Turn: 307 Action list: ['m u_30 e', 'dl 4 6 15 12']
# Super secret. Turn: 308 Action list: ['m u_32 e', 'dl 5 7 15 12']
# Super secret. Turn: 309 Action list: ['m u_30 e', 'dl 5 6 15 12']
# Super secret. Turn: 310 Action list: ['m u_32 e', 'dl 6 7 15 12']
# Super secret. Turn: 311 Action list: []
# Super secret. Turn: 312 Action list: ['bw 1 7']
# Well.. Shit. I'm unit, u_46 Apparently I can't find any resources.
# Super secret. Turn: 313 Action list: []
# Well.. Shit. I'm unit, u_46 Apparently I can't find any resources.
# Super secret. Turn: 314 Action list: ['bw 0 6']
# Well.. Shit. I'm unit, u_46 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_47 Apparently I can't find any resources.
# Super secret. Turn: 315 Action list: []
# Well.. Shit. I'm unit, u_46 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_47 Apparently I can't find any resources.
# Super secret. Turn: 316 Action list: []
# Well.. Shit. I'm unit, u_46 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_47 Apparently I can't find any resources.
# Super secret. Turn: 317 Action list: []
# Well.. Shit. I'm unit, u_46 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_47 Apparently I can't find any resources.
# Super secret. Turn: 318 Action list: []
# Well.. Shit. I'm unit, u_46 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_47 Apparently I can't find any resources.
# Super secret. Turn: 319 Action list: []
# Super secret. Turn: 320 Action list: ['m u_46 e', 'dl 1 7 15 12', 'm u_47 e', 'dl 0 6 15 12']
# Super secret. Turn: 321 Action list: []
# Super secret. Turn: 322 Action list: ['r 1 7', 'm u_46 e', 'dl 2 7 15 12', 'm u_47 e', 'dl 1 6 15 12']
# Super secret. Turn: 323 Action list: []
# Super secret. Turn: 324 Action list: ['r 0 6', 'm u_46 e', 'dl 3 7 15 12', 'm u_47 e', 'dl 2 6 15 12']
# Super secret. Turn: 325 Action list: []
# Super secret. Turn: 326 Action list: ['m u_46 e', 'dl 4 7 15 12', 'm u_47 e', 'dl 3 6 15 12']
# Super secret. Turn: 327 Action list: []
# Super secret. Turn: 328 Action list: ['m u_46 e', 'dl 5 7 15 12', 'm u_47 e', 'dl 4 6 15 12']
# Super secret. Turn: 329 Action list: []
# Super secret. Turn: 330 Action list: ['m u_46 e', 'dl 6 7 15 12', 'm u_47 e', 'dl 5 6 15 12']
# Super secret. Turn: 331 Action list: []
# Super secret. Turn: 332 Action list: ['r 1 7', 'm u_46 e', 'dl 7 7 15 12', 'm u_47 e', 'dl 6 6 15 12']
# Super secret. Turn: 333 Action list: []
# Super secret. Turn: 334 Action list: ['r 0 6', 'm u_46 e', 'dl 8 7 15 12', 'm u_47 e', 'dl 7 6 15 12']
# Super secret. Turn: 335 Action list: []
# Super secret. Turn: 336 Action list: ['m u_46 e', 'dl 9 7 15 12', 'm u_47 e', 'dl 8 6 15 12']
# Super secret. Turn: 337 Action list: []
# Super secret. Turn: 338 Action list: ['m u_46 e', 'dl 10 7 15 12', 'm u_47 e', 'dl 9 6 15 12']
# Super secret. Turn: 339 Action list: []
# Super secret. Turn: 340 Action list: ['m u_46 e', 'dl 11 7 15 12', 'm u_47 e', 'dl 10 6 15 12']
# Super secret. Turn: 341 Action list: []
# Super secret. Turn: 342 Action list: ['r 1 7', 'm u_46 e', 'dl 12 7 15 12', 'm u_47 e', 'dl 11 6 15 12']
# Super secret. Turn: 343 Action list: []
# Super secret. Turn: 344 Action list: ['r 0 6', 'm u_46 e', 'dl 13 7 15 12', 'm u_47 e', 'dl 12 6 15 12']
# Super secret. Turn: 345 Action list: []
# Super secret. Turn: 346 Action list: ['m u_46 e', 'dl 14 7 15 12', 'm u_47 e', 'dl 13 6 15 12']
# Super secret. Turn: 347 Action list: []
# Super secret. Turn: 348 Action list: ['m u_46 s', 'dl 15 7 15 12', 'm u_47 e', 'dl 14 6 15 12']
# Super secret. Turn: 349 Action list: []
# Super secret. Turn: 350 Action list: ['m u_46 s', 'dl 15 8 15 12', 'm u_47 s', 'dl 15 6 15 12']
# Super secret. Turn: 351 Action list: []
# Super secret. Turn: 352 Action list: ['bw 1 7']
# Well.. Shit. I'm unit, u_48 Apparently I can't find any resources.
# Super secret. Turn: 353 Action list: []
# Well.. Shit. I'm unit, u_48 Apparently I can't find any resources.
# Super secret. Turn: 354 Action list: ['bw 0 6']
# Well.. Shit. I'm unit, u_48 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_49 Apparently I can't find any resources.
# Super secret. Turn: 355 Action list: []
# Well.. Shit. I'm unit, u_48 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_49 Apparently I can't find any resources.
# Super secret. Turn: 356 Action list: []
# Well.. Shit. I'm unit, u_48 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_49 Apparently I can't find any resources.
# Super secret. Turn: 357 Action list: []
# Well.. Shit. I'm unit, u_48 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_49 Apparently I can't find any resources.
# Super secret. Turn: 358 Action list: []
# Well.. Shit. I'm unit, u_48 Apparently I can't find any resources.
# Well.. Shit. I'm unit, u_49 Apparently I can't find any resources.
# Super secret. Turn: 359 Action list: []

# %%
# Press shift+O (toggle outputs) to let the output be the whole size
# Display the graphic of the game you just ran
env.render(mode="ipython", width=1200, height=800)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;0fc11e23-0801-11ec-9d45-2cf05d56c6f7&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.0.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;seed&quot;: 367618709,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;number&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 32,
#             &quot;height&quot;: 32,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;32 32&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r uranium 0 0 304&quot;,
#               &quot;r coal 0 7 383&quot;,
#               &quot;r uranium 0 24 311&quot;,
#               &quot;r uranium 0 25 320&quot;,
#               &quot;r wood 0 31 359&quot;,
#               &quot;r wood 1 14 381&quot;,
#               &quot;r wood 1 15 300&quot;,
#               &quot;r wood 2 14 300&quot;,
#               &quot;r wood 2 15 358&quot;,
#               &quot;r wood 3 11 380&quot;,
#               &quot;r wood 3 12 316&quot;,
#               &quot;r wood 3 13 394&quot;,
#               &quot;r wood 4 0 313&quot;,
#               &quot;r wood 4 1 331&quot;,
#               &quot;r wood 4 12 358&quot;,
#               &quot;r wood 4 13 331&quot;,
#               &quot;r wood 5 0 303&quot;,
#               &quot;r wood 5 1 318&quot;,
#               &quot;r wood 5 12 367&quot;,
#               &quot;r wood 5 13 345&quot;,
#               &quot;r coal 5 27 419&quot;,
#               &quot;r coal 5 28 371&quot;,
#               &quot;r wood 6 0 303&quot;,
#               &quot;r wood 6 5 800&quot;,
#               &quot;r wood 6 11 392&quot;,
#               &quot;r coal 6 27 377&quot;,
#               &quot;r coal 6 28 359&quot;,
#               &quot;r wood 7 1 318&quot;,
#               &quot;r wood 7 5 800&quot;,
